# %%
import googleapiclient.discovery
import streamlit as st
import pymongo as pymg
import psycopg2 as psyc
import pandas as pd
import mysql.connector
#import sqlalchemy as sq

# %%
def api_connection():
    api_service_name = "youtube"
    api_version = "v3"
    api_key='AIzaSyAiq_ny9D0TCF9kQaJSXC-y2dw-5IqX3vI'
    youtube = googleapiclient.discovery.build(api_service_name, api_version, developerKey=api_key)
    return youtube    
    
youtube=api_connection()

# %%
def get_channel_details(c_id):
   request=youtube.channels().list(
   part="snippet,contentDetails,statistics",
   id=c_id
   )
   response = request.execute()

   for i in response['items']:
        print(i)
        data = {"Channel_Id":i["id"],
                "Channel_Name":i['snippet']['title'],
                "Channel_Description":i['snippet']['description'],
                "PublishedAt":i['snippet']['publishedAt'],
                "Playlist_Id":i['contentDetails']['relatedPlaylists']['uploads'],
                "Subscribers":i['statistics']['subscriberCount'],
                "Channel_views":i['statistics']['viewCount'],
                "Total_Videos":i['statistics']['videoCount']
                }

   return data

# %%
channel_info=get_channel_details("UCr-gTfI7au9UaEjNCbnp_Nw")
channel_info

#channel_content('UCr-gTfI7au9UaEjNCbnp_Nw')
#channel_content("UC_YTdl80Ebsje31dLyQ_Q_Q")
#channel_content('UChtZAhQar8frqy5Ba6aTgcQ')
#channel_content("UC05To9qf3iebfmn24zTvqdg")
#channel_content('UCltRUjPwsL-n4_rbuk6DjSQ')
# Out:
# {'kind': 'youtube#channel', 'etag': 'dBKE-dHNAJNHYfArFRlGPYhdCD8', 'id': 'UCr-gTfI7au9UaEjNCbnp_Nw', 'snippet': {'title': 'Vidya Vox', 'description': "Hey guys, I'm Vidya Vox! Welcome to my YouTube channel :) I'm so excited to share my original music, mashups and covers with you. My music fuses many traditional Indian genres with Western Pop and Electronic influences. Musician and producer Shankar Tucker produces all of the songs and videos you'll find on this channel. We hope you enjoy listening to our creations! Thank you for being a part of our journey, and if you'd like instant updates, check out my social media accounts below!", 'customUrl': '@vidyavox', 'publishedAt': '2014-03-14T13:12:26Z', 'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/1Sk_k49zb487KUd_V2OEkNOsFrN4iynVSFaymp1stDG5SObByyOf4Y8RQI7waJN2mASJUzKHSg=s88-c-k-c0x00ffffff-no-nd-rj', 'width': 88, 'height': 88}, 'medium': {'url': 'https://yt3.ggpht.com/1Sk_k49zb487KUd_V2OEkNOsFrN4iynVSFaymp1stDG5SObByyOf4Y8RQI7
# ...

# %%
#for a given channel id,fetch the Playlist_ID of all videos and video_ID for each video
def get_video_ids(channel_info):
    video_ids=[]
    v_plid=channel_info['Playlist_Id']
    next_page_token=None

    while True:
        request1=youtube.playlistItems().list(part="snippet,contentDetails", playlistId = v_plid,maxResults=50,pageToken=next_page_token)
        response1=request1.execute()

        for i in range(len(response1['items'])):
            video_ids.append(response1['items'][i]['snippet']['resourceId']['videoId'])

        next_page_token=response1.get('nextPageToken')

        if next_page_token is None:
            break

    return video_ids

# %%
video_ids=get_video_ids(channel_info)
video_ids
#tx1UQseMJpk
# Out:
# ['naAwiCtxndQ',
#  'WzyfatXppwo',
#  'tx1UQseMJpk',
#  '52jCUplBKd8',
#  'x7RIFbuaKS4',
#  'yDyb0HIQby0',
#  'DagqIHmkadM',
#  'aQEgnwvW2OY',
#  'M-gXuceWwf4',
#  'mSYxNMdwzUc',
#  'Qc7E9CZUHb4',
#  '9qOwRb5mIl0',
#  'xEPfCl_Frhs',
#  'Z9VhzKI3CVM',
#  'nWa6aFWopA8',
#  '-NFueNFvTuE',
#  'k6WJxHPDI6w',
#  '7uLEzxdXuiA',
#  'C_1Dp4a-4VM',
#  'ZJ9uh0BVJy0',
#  '_mpv6eiuEHI',
#  'Q-TTKm2kEe8',
#  'jOmktpt_nBE',
#  'h6BQqGrLLJM',
#  'Ip4CB7hlPcw',
#  'RDMJWI0pUcE',
#  'bhmQMrmG8d8',
#  'ICkESUQRWWk',
#  'Y-EDa1cIGiM',
#  '57XUSY4PKDY',
#  '_UtIeYxcxUc',
#  'CAe43gSJQCQ',
#  'LPJKJLVTbVE',
#  'zc_BAnxjG2A',
#  'uT_z4BZpcZc',
#  'pDe_NSgZUX8',
#  'TDymoXfczY0',
#  '7xaftUFlAfo',
#  'DXuB-pMG2NI',
#  '4zRqjS9g_XE',
#  'UiegvMvLopE',
#  'w9KjZpuWmNw',
#  'yDMOsIr7SB0',
#  '3tPV6-J0QBo',
#  'oOQscFU8PCs',
#  'rcxzlzDyTZY',
#  'u0S0c0GfOsM',
#  '_LMUBoIzgOk',
#  'IBCAZRhiiHI',
#  'cBr9hb3MysY',
#  'T3-Ypyzd5kc',
#  'MBl7acFySUg',
#  'k7goZTH1u30',
#  'MieUYmKj5z8',
#  'l6C6sgE_YFw',
# ...

# %%
def time_duration(t):
    a = pd.Timedelta(t)
    b = str(a).split()[-1]
    return b

# %%
def get_video_details(video_ids):
    video_content=[]
    for i in video_ids:
        request2=youtube.videos().list(part="snippet,contentDetails,statistics",id=i)
        response2 = request2.execute()
        
        for j in response2['items']:
            data = {"Video_Id":j['id'],
                    "Channel_Id":j['snippet']['channelId'],
                    "Title":j['snippet']['title'],
                    "Channel_Name":j['snippet']['channelTitle'],
                    "Description":j['snippet']['description'],
                    "PublishedAt":j['snippet']['publishedAt'],
                    "Tags":j['snippet'].get('tags'),
                    "Thumbnail":j['snippet']['thumbnails']['default']['url'],
                    "Duration":time_duration(j['contentDetails']['duration']),
                    "contentRating":j['contentDetails']['contentRating'],
                    "Caption":j['contentDetails']['caption'],
                    "licensedContent":j['contentDetails']['licensedContent'],
                    "Definition":j['contentDetails']['definition'],
                    "View_count":j['statistics']['viewCount'],
                    "Like_count":j['statistics'].get('likeCount'),
                    "Comment_count":j['statistics']['commentCount'],
                    "Fav_count":j['statistics']['favoriteCount']
                    }
            video_content.append(data)
    return video_content

# %%
video_info=get_video_details(video_ids)
video_info
# Out:
# [{'Video_Id': 'naAwiCtxndQ',
#   'Channel_Id': 'UCr-gTfI7au9UaEjNCbnp_Nw',
#   'Title': 'Thilaana Thilaana - Disco Rani Sessions Vol. 1',
#   'Channel_Name': 'Vidya Vox',
#   'Description': '',
#   'PublishedAt': '2024-05-06T15:49:38Z',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/naAwiCtxndQ/default.jpg',
#   'Duration': '00:01:01',
#   'contentRating': {},
#   'Caption': 'false',
#   'licensedContent': False,
#   'Definition': 'hd',
#   'View_count': '6164',
#   'Like_count': '431',
#   'Comment_count': '14',
#   'Fav_count': '0'},
#  {'Video_Id': 'WzyfatXppwo',
#   'Channel_Id': 'UCr-gTfI7au9UaEjNCbnp_Nw',
#   'Title': "What if this classic Bollywood tune was an 80's pop song?",
#   'Channel_Name': 'Vidya Vox',
#   'Description': 'Usha Uthup\'s "Auva Auva" covered by Vidya Vox. \nMore classic bollywood disco tunes coming soon in "DiscoRani"',
#   'PublishedAt': '2024-04-23T03:47:15Z',
#   'Tags': None,
# ...

# %%
def get_comment_details(video_ids):
    comment_content=[]
    try:
        for i in video_ids:
            request=youtube.commentThreads().list(part="snippet",videoId=i,maxResults=50)
            response=request.execute()

            for j in response['items']:
                data= {"Comment_Id":j['snippet']['topLevelComment']['id'],
                        "Video_Id":j['snippet']['topLevelComment']['snippet']['videoId'],
                        "Comment_Text":j['snippet']['topLevelComment']['snippet']['textDisplay'],
                        "Comment_Author":j['snippet']['topLevelComment']['snippet']['authorDisplayName'],
                        "Comment_Published":j['snippet']['topLevelComment']['snippet']['publishedAt'] }
                
                comment_content.append(data)

    except:
        pass
    return comment_content

# %%
comment_info=get_comment_details(video_ids)
comment_info
# Out:
# [{'Comment_Id': 'UgyjrTe-p2T81oOf96V4AaABAg',
#   'Video_Id': 'naAwiCtxndQ',
#   'Comment_Text': 'Sing the Telugu version',
#   'Comment_Author': '@HiSya732',
#   'Comment_Published': '2024-05-07T21:18:29Z'},
#  {'Comment_Id': 'UgywmzP2bE3L-UfVIFJ4AaABAg',
#   'Video_Id': 'naAwiCtxndQ',
#   'Comment_Text': 'Nice 🥰🥰🥰',
#   'Comment_Author': '@RanjithRanju-gs8jn',
#   'Comment_Published': '2024-05-07T17:54:28Z'},
#  {'Comment_Id': 'UgwYvLhh1Qjn95sRKXR4AaABAg',
#   'Video_Id': 'naAwiCtxndQ',
#   'Comment_Text': 'Vidya roxx',
#   'Comment_Author': '@bankimbiswal9400',
#   'Comment_Published': '2024-05-07T08:15:40Z'},
#  {'Comment_Id': 'UgzEBDTjIyjDD3pdDnt4AaABAg',
#   'Video_Id': 'naAwiCtxndQ',
#   'Comment_Text': 'Very nice song❤',
#   'Comment_Author': '@Desilife91',
#   'Comment_Published': '2024-05-07T03:05:15Z'},
#  {'Comment_Id': 'UgxGpK9JOiEnXxeU_ih4AaABAg',
#   'Video_Id': 'naAwiCtxndQ',
#   'Comment_Text': 'Iam big fan of you ❤',
#   'Comment_Author': '@user-du4kc9up4o',
# ...

# %%
def get_playlist_details(channel_info):
    playlist_data=[]
    pl_c_id=channel_info['Channel_Id']
    next_page_token=None

    while True:
        request=youtube.playlists().list(part="snippet,contentDetails",channelId=pl_c_id,maxResults=50, pageToken=next_page_token)
        response=request.execute()

        for i in response['items']:
            data={"Playlist_Id":i['id'],
                    "Title":i['snippet']['title'],
                    "Channel_Id":i['snippet']['channelId'],
                    "Channel_Name":i['snippet']['channelTitle'],
                    "PublishedAt":i['snippet']['publishedAt'],
                    "Video_Count":i['contentDetails']['itemCount']}
            playlist_data.append(data)

        next_page_token=response.get('nextPageToken')
        if next_page_token is None:
            break
    return playlist_data

# %%
playlist_info=get_playlist_details(channel_info)
playlist_info
# Out:
# [{'Playlist_Id': 'PLjOy3wobFPwt2RrWvfN_ElkuPyk7mvRpo',
#   'Title': 'DiscoRani Sessions Vol. 1',
#   'Channel_Id': 'UCr-gTfI7au9UaEjNCbnp_Nw',
#   'Channel_Name': 'Vidya Vox',
#   'PublishedAt': '2024-04-23T19:02:19Z',
#   'Video_Count': 2},
#  {'Playlist_Id': 'PLjOy3wobFPwsOwVskbGiSO0vL2YUR9Rr5',
#   'Title': 'Behind The Scenes | Vidya Vox',
#   'Channel_Id': 'UCr-gTfI7au9UaEjNCbnp_Nw',
#   'Channel_Name': 'Vidya Vox',
#   'PublishedAt': '2016-10-13T20:10:06Z',
#   'Video_Count': 6},
#  {'Playlist_Id': 'PLjOy3wobFPwtEpmLVdAzIat0_yNt8i5jX',
#   'Title': 'Latest Videos | Vidya Vox',
#   'Channel_Id': 'UCr-gTfI7au9UaEjNCbnp_Nw',
#   'Channel_Name': 'Vidya Vox',
#   'PublishedAt': '2016-08-17T18:08:02Z',
#   'Video_Count': 60},
#  {'Playlist_Id': 'PLjOy3wobFPwvjX-hEWGwXVkrJrcLeEkUz',
#   'Title': 'Popular Videos | Vidya Vox',
#   'Channel_Id': 'UCr-gTfI7au9UaEjNCbnp_Nw',
#   'Channel_Name': 'Vidya Vox',
#   'PublishedAt': '2015-09-09T21:48:51Z',
#   'Video_Count': 60},
# ...

# %%
#def MongoDB_upload():
client=pymg.MongoClient("mongodb+srv://maheshwariswaminathan:ocJ5zarf3JSDRQu3@cluster0.gf3ephp.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0")
db=client["Youtube_Content"]

# %%
def channel_content(Channel_ID):
    channel_info=get_channel_details(Channel_ID)
    playlist_info=get_playlist_details(channel_info)
    all_video_ids=get_video_ids(channel_info)
    video_info=get_video_details(all_video_ids)
    comment_info=get_comment_details(all_video_ids)
    
    coll1=db["channel_content"]
    coll1.delete_one({'channel_information.Channel_Id' : Channel_ID})
    coll1.insert_one({"channel_information":channel_info,
                        "playlist_information":playlist_info,
                        "all_video_ids":all_video_ids,
                        "video_information":video_info,
                        "comment_information":comment_info})
    
    return "uploaded information in the mongoDB successfully"

# %%
channel_content('UCr-gTfI7au9UaEjNCbnp_Nw')
#channel_content("UC_YTdl80Ebsje31dLyQ_Q_Q")
#channel_content('UCltRUjPwsL-n4_rbuk6DjSQ')
#channel_content('UCr-gTfI7au9UaEjNCbnp_Nw')
# Out:
# {'kind': 'youtube#channel', 'etag': 'dBKE-dHNAJNHYfArFRlGPYhdCD8', 'id': 'UCr-gTfI7au9UaEjNCbnp_Nw', 'snippet': {'title': 'Vidya Vox', 'description': "Hey guys, I'm Vidya Vox! Welcome to my YouTube channel :) I'm so excited to share my original music, mashups and covers with you. My music fuses many traditional Indian genres with Western Pop and Electronic influences. Musician and producer Shankar Tucker produces all of the songs and videos you'll find on this channel. We hope you enjoy listening to our creations! Thank you for being a part of our journey, and if you'd like instant updates, check out my social media accounts below!", 'customUrl': '@vidyavox', 'publishedAt': '2014-03-14T13:12:26Z', 'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/1Sk_k49zb487KUd_V2OEkNOsFrN4iynVSFaymp1stDG5SObByyOf4Y8RQI7waJN2mASJUzKHSg=s88-c-k-c0x00ffffff-no-nd-rj', 'width': 88, 'height': 88}, 'medium': {'url': 'https://yt3.ggpht.com/1Sk_k49zb487KUd_V2OEkNOsFrN4iynVSFaymp1stDG5SObByyOf4Y8RQI7
# ...

# %%
Channel_ID = 'UCltRUjPwsL-n4_rbuk6DjSQ'
ch_list=[]
db=client["Youtube_Content"]
coll1=db["channel_content"]

for ch_data in coll1.find({'channel_information.Channel_Id' : Channel_ID},{"_id":0,"channel_information":1}):
    ch_list.append(ch_data["channel_information"])    

#print(ch_list)
df_channel_info=pd.DataFrame(ch_list)
df_channel_info
# Out:
#                  Channel_Id     Channel_Name Channel_Description  \
# 0  UCltRUjPwsL-n4_rbuk6DjSQ  Amrutham Gamaya
#
#             PublishedAt               Playlist_Id Subscribers Channel_views  \
# 0  2015-11-18T09:50:58Z  UUltRUjPwsL-n4_rbuk6DjSQ       97000      31172806
#
#   Total_Videos
# 0            3

# %%
mydb=psyc.connect(host="localhost",
                    user="postgres",
                    password="maksi@2024",
                    database="Youtube_Content",
                    port="5432")
cursor=mydb.cursor()

for index,row in df_channel_info.iterrows():
    insert_sql='''insert into channels(Channel_Name,
                                       Channel_Id,
                                       Subscribers,
                                       Channel_Views,
                                       Total_Videos,
                                       Channel_Description,
                                       Playlist_Id)
    
                                       values(%s,%s,%s,%s,%s,%s,%s)
                                       on conflict (Channel_Id)
                                       do update set Channel_Name = EXCLUDED.Channel_Name,
                                       Subscribers = EXCLUDED.Subscribers,
                                       Channel_Views = EXCLUDED.Channel_Views,
                                       Total_Videos = EXCLUDED.Total_Videos,
                                       Channel_Description = EXCLUDED.Channel_Description,
                                       Playlist_Id = EXCLUDED.Playlist_Id'''

    values=(row["Channel_Name"],
            row["Channel_Id"],
            row["Subscribers"],
            row["Channel_views"],
            row["Total_Videos"],
            row["Channel_Description"],
            row["Playlist_Id"])  
    try:
        cursor.execute(insert_sql,values)      
        mydb.commit()
    except Exception as error:
        print("Error occured during insertion",error)
        mydb.rollback()

# %%
mydb=psyc.connect(host="localhost",
                    user="postgres",
                    password="maksi@2024",
                    database="Youtube_Content",
                    port="5432")
cursor=mydb.cursor()

cursor.execute("select Channel_Name from Channels")
s = cursor.fetchall()
s = [i[0] for i in s]
s.sort(reverse=False)
print(s)


if s == []:
    #st.info
    print("The SQL database is currently empty")

else:
    #st.subheader
    print("List of channels in SQL database")
    c = 1
    for i in s:
        #st.write
        print(str(c) + ' - ' + i)
        c += 1
        print(i)
        print(s)
# Out:
# ['Amrutham Gamaya', 'UChtZAhQar8frqy5Ba6aTgcQ', 'Varsha Sreenivas', 'Vidya Vox', 'krish']
# List of channels in SQL database
# 1 - Amrutham Gamaya
# Amrutham Gamaya
# ['Amrutham Gamaya', 'UChtZAhQar8frqy5Ba6aTgcQ', 'Varsha Sreenivas', 'Vidya Vox', 'krish']
# 2 - UChtZAhQar8frqy5Ba6aTgcQ
# UChtZAhQar8frqy5Ba6aTgcQ
# ['Amrutham Gamaya', 'UChtZAhQar8frqy5Ba6aTgcQ', 'Varsha Sreenivas', 'Vidya Vox', 'krish']
# 3 - Varsha Sreenivas
# Varsha Sreenivas
# ['Amrutham Gamaya', 'UChtZAhQar8frqy5Ba6aTgcQ', 'Varsha Sreenivas', 'Vidya Vox', 'krish']
# 4 - Vidya Vox
# Vidya Vox
# ['Amrutham Gamaya', 'UChtZAhQar8frqy5Ba6aTgcQ', 'Varsha Sreenivas', 'Vidya Vox', 'krish']
# 5 - krish
# krish
# ['Amrutham Gamaya', 'UChtZAhQar8frqy5Ba6aTgcQ', 'Varsha Sreenivas', 'Vidya Vox', 'krish']

# %%
# mongo_operations.load_mongoDB("UCr-gTfI7au9UaEjNCbnp_Nw", dict)
# postgres_operations.load_into_db("UCr-gTfI7au9UaEjNCbnp_Nw")

# %%
client=pymg.MongoClient("mongodb+srv://maheshwariswaminathan:ocJ5zarf3JSDRQu3@cluster0.gf3ephp.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0")
db=client["Youtube_Content"]

pl_list=[]
db=client["Youtube_Content"]
coll1=db["channel_content"]

#Channel_ID = 'UCr-gTfI7au9UaEjNCbnp_Nw'
for pl_data in coll1.find({},{"_id":0,"playlist_information":1}):
    print(pl_data)
    for i in range(len(pl_data["playlist_information"])):
        pl_list.append(pl_data["playlist_information"][i])

df_playlist_info=pd.DataFrame(pl_list)
df_playlist_info


mydb=psyc.connect(host="localhost",
                    user="postgres",
                    password="maksi@2024",
                    database="Youtube_Content",
                    port="5432")
cursor=mydb.cursor()

for index,row in df_playlist_info.iterrows():
    #print("Row values: ", row)
    insert_sql='''insert into playlist(Playlist_Id,
                                        Title,
                                        Channel_Id,
                                        Channel_Name,
                                        PublishedAt,
                                        Total_Videos)
    
                                       values(%s,%s,%s,%s,%s,%s)
                                       on conflict (Playlist_Id)
                                       do update set Title = EXCLUDED.Title,
                                       Channel_Id = EXCLUDED.Channel_Id,
                                       Channel_Name = EXCLUDED.Channel_Name,
                                       PublishedAt = EXCLUDED.PublishedAt,
                                       Total_Videos = EXCLUDED.Total_Videos'''

    values=(row["Playlist_Id"],
            row["Title"],
            row["Channel_Id"],
            row["Channel_Name"],
            row["PublishedAt"],
            row["Video_Count"]
            )  
    try:
        cursor.execute(insert_sql,values)      
        mydb.commit()
    except Exception as error:
        print("Error occured during insertion",error)
        mydb.rollback()

# %%
dict={'channel_info': {'thumbnail' : "URL"}}
print(dict['channel_info']['thumbnail'])
# Out:
# URL

# %%
client=pymg.MongoClient("mongodb+srv://maheshwariswaminathan:ocJ5zarf3JSDRQu3@cluster0.gf3ephp.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0")
db=client["Youtube_Content"]

pld_list=[]
db=client["Youtube_Content"]
coll1=db["channel_content"]

#Channel_ID = 'UCr-gTfI7au9UaEjNCbnp_Nw'
for pld_data in coll1.find({},{"_id":0,"video_information":1}):
    #print(pl_data)
    for i in range(len(pld_data["video_information"])):
        pld_list.append(pld_data["video_information"][i])

df_playlist_inf=pd.DataFrame(pld_list)
df_playlist_inf
# Out:
#        Video_Id                Channel_Id  \
# 0   WzyfatXppwo  UCr-gTfI7au9UaEjNCbnp_Nw
# 1   tx1UQseMJpk  UCr-gTfI7au9UaEjNCbnp_Nw
# 2   52jCUplBKd8  UCr-gTfI7au9UaEjNCbnp_Nw
# 3   x7RIFbuaKS4  UCr-gTfI7au9UaEjNCbnp_Nw
# 4   yDyb0HIQby0  UCr-gTfI7au9UaEjNCbnp_Nw
# ..          ...                       ...
# 90  lVIUzKiZfms  UCr-gTfI7au9UaEjNCbnp_Nw
# 91  9ZsRQNUQ8Vo  UCr-gTfI7au9UaEjNCbnp_Nw
# 92  nxzMkpNxau4  UCr-gTfI7au9UaEjNCbnp_Nw
# 93  AExTAC1d1zA  UCr-gTfI7au9UaEjNCbnp_Nw
# 94  Rw9EiwUn4Yg  UCr-gTfI7au9UaEjNCbnp_Nw
#
#                                                 Title Channel_Name  \
# 0   What if this classic Bollywood tune was an 80'...    Vidya Vox
# 1   Vidya Vox - “Auva Auva” (Usha Uthup, Bappi Lah...    Vidya Vox
# 2   Vidya Vox - Romance (Runa Laila) - DiscoRani S...    Vidya Vox
# 3                                     Happy Diwali 🪔🪔    Vidya Vox
# 4                             New Haircut Vibes 💇🏾‍♀️    Vidya Vox
# ...

# %%
# Table creation for the channels,playlists,videos,comments
def Channels(channel_content):
    mydb=psyc.connect(host="localhost",
                        user="postgres",
                        password="maksi@2024",
                        database="Youtube_Content",
                        port="5432")
    cursor=mydb.cursor()

    try:
        create_query='''create table if not exists channels(Channel_Id varchar(80) primary key,
                                                            Channel_Name varchar(100),
                                                            Subscribers bigint,
                                                            Channel_views bigint,
                                                            Total_Videos int,
                                                            Channel_Description text,
                                                            Playlist_Id varchar(80))'''
        cursor.execute(create_query)
        mydb.commit()

    except:
        print("Channels table already created")

# ch_list= []
# ch_list2= []
# df_channels= pd.DataFrame(table)

# print(df_channels)
# ch_list.append(df_channels[0])
# for i in ch_list[0]:
#     ch_list2.append(i)
# print(ch_list)


# if channel_content in ch_list2:
#     msg= f"Your Provided Channel {channel_content} is Already exists"        
#     return msg  

# # else:

# single_channel_details= []
# coll1=db["Youtube_Content"]
# for ch_data in coll1.find({"channel_information.Channel_Name":channel_content},{"_id":0}):
#     single_channel_details.append(ch_data["channel_information"])

# print(single_channel_details)    

#     df_single_channel= pd.DataFrame(single_channel_details)

#     for index,row in df_single_channel.iterrows():
#         insert_query='''insert into channels(Channel_Name ,
#                                             Channel_Id,
#                                             Subscribers,
#                                             Channel_Views,
#                                             Total_Videos,
#                                             Channel_Description,
#                                             Playlist_Id)
                                            
#                                             values(%s,%s,%s,%s,%s,%s,%s)'''
#         values=(row['Channel_Name'],
#                 row['Channel_Id'],
#                 row['Subscribers'],
#                 row['Channel_Views'],
#                 row['Total_Videos'],
#                 row['Channel_Description'],
#                 row['Playlist_Id'])

#         try:
#             cursor.execute(insert_query,values)
#             mydb.commit()

#         except:
#             print("Channel values are already inserted")

# %%
# create_query='''create table if not exists videos(Video_Id varchar(100) primary key,
#                                                     Channel_Id varchar(100),
#                                                     Title varchar(150),
#                                                     Channel_Name varchar(100),
#                                                     Description text,
#                                                     PublishedAt timestamp,
#                                                     Tags text,
#                                                     Thumbnail varchar(200),
#                                                     Duration interval,
#                                                     Caption varchar(100),
#                                                     Definition varchar(10),
#                                                     View_Count bigint,
#                                                     Like_Count bigint,
#                                                     Comment_Count bigint,
#                                                     Fav_Count bigint
#                                                         )'''

# cursor.execute(create_query)
# mydb.commit()


client=pymg.MongoClient("mongodb+srv://maheshwariswaminathan:ocJ5zarf3JSDRQu3@cluster0.gf3ephp.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0")
db=client["Youtube_Content"]

vi_list=[]
db=client["Youtube_Content"]
coll1=db["channel_content"]

Channel_ID = 'UCr-gTfI7au9UaEjNCbnp_Nw'
for vi_data in coll1.find({},{"_id":0,"video_information":1}):
    #print(pl_data)
    for i in range(len(vi_data["video_information"])):
        vi_list.append(vi_data["video_information"][i])

df_video_inf=pd.DataFrame(vi_list)
df_video_inf

mydb=psyc.connect(host="localhost",
                    user="postgres",
                    password="maksi@2024",
                    database="Youtube_Content",
                    port="5432")
cursor=mydb.cursor()

for index,row in df_video_inf.iterrows():
    insert_sql='''insert into videos(Video_Id,
                                Channel_Id,
                                Title,            
                                Channel_Name,
                                Description,
                                PublishedAt,
                                Tags,
                                Thumbnail,
                                Duration,
                                Caption,
                                Definition,
                                View_count,
                                Like_count,
                                Comment_count,
                                Fav_count )
                            
                            values(%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
                            on conflict (Video_Id)
                            do update set Channel_Id = EXCLUDED.Channel_Id,
                            Title = EXCLUDED.Title,
                            Channel_Name = EXCLUDED.Channel_Name,
                            Description = EXCLUDED.Description,
                            PublishedAt = EXCLUDED.PublishedAt,
                            Tags = EXCLUDED.Tags,
                            Thumbnail = EXCLUDED.Thumbnail,
                            Duration = EXCLUDED.Duration,
                            Caption = EXCLUDED.Caption,
                            Definition = EXCLUDED.Definition,
                            View_Count = EXCLUDED.View_count,
                            Like_Count = EXCLUDED.Like_count,
                            Comment_Count = EXCLUDED.Comment_count,
                            Fav_Count = EXCLUDED.Fav_count '''
        

    values=(row["Video_Id"],
            row["Channel_Id"],
            row["Title"],            
            row["Channel_Name"],
            row["Description"],
            row["PublishedAt"],
            row["Tags"],
            row["Thumbnail"],
            row["Duration"],
            row["Caption"],
            row["Definition"],
            row["View_count"],
            row["Like_count"],
            row["Comment_count"],
            row["Fav_count"]
            )
    try:
        cursor.execute(insert_sql,values)
        mydb.commit()
    except Exception as error:
        print("Video values are already inserted",error)

# %%
# client=pymg.MongoClient("mongodb+srv://maheshwariswaminathan:ocJ5zarf3JSDRQu3@cluster0.gf3ephp.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0")
# db=client["Youtube_Content"]

mydb=psyc.connect(host="localhost",
                    user="postgres",
                    password="maksi@2024",
                    database="Youtube_Content",
                    port="5432")
cursor=mydb.cursor()

try:
    create_query='''create table if not exists Comments_tbl(Comment_Id varchar(100) primary key,
                                                        Video_Id varchar(100),
                                                        Comment_Text varchar(80),
                                                        Comment_Author varchar(100),
                                                        PublishedAt timestamp
                                                        )'''
                                            
    cursor.execute(create_query)
    mydb.commit()

except Exception as error:
    print("Comment table already created",error)

# %%
cm_list=[]
db=client["Youtube_Content"]
coll1=db["channel_content"]


Channel_Id="UCr-gTfI7au9UaEjNCbnp_Nw"
for cm_data in coll1.find({},{"_id":0,"comment_information":1}):
    for i in range(len(cm_data["comment_information"])):
        cm_list.append(cm_data["comment_information"][i])
#print(cm_list)
df_comment_info=pd.DataFrame(cm_list)
#df_comment_info


mydb=psyc.connect(host="localhost",
                    user="postgres",
                    password="maksi@2024",
                    database="Youtube_Content",
                    port="5432")
cursor=mydb.cursor()

for index,row in df_comment_info.iterrows():

    insert_sql='''insert into Comments_tbl(Comment_Id,
                                    Video_Id,
                                    Comment_Text,
                                    Comment_Author,
                                    PublishedAt )
                            
                                    values(%s,%s,%s,%s,%s)
                                    on conflict (Comment_Id)
                                    do update set Video_Id = EXCLUDED.Video_Id,
                                    Comment_Text = EXCLUDED.Comment_Text,
                                    Comment_Author = EXCLUDED.Comment_Author,
                                    PublishedAt = EXCLUDED.PublishedAt '''
        

    values=(row["Comment_Id"],
            row["Video_Id"],
            row["Comment_Text"],            
            row["Comment_Author"],
            row["Comment_Published"]
            )
    try:
        cursor.execute(insert_sql,values)
        mydb.commit()
    except Exception as error:
        print("Comment values are already inserted",error)   
        mydb.rollback()
# Out:
# Comment values are already inserted value too long for type character varying(80)
#
# Comment values are already inserted current transaction is aborted, commands ignored until end of transaction block
#
# Comment values are already inserted current transaction is aborted, commands ignored until end of transaction block
#
# Comment values are already inserted current transaction is aborted, commands ignored until end of transaction block
#
# Comment values are already inserted current transaction is aborted, commands ignored until end of transaction block
#
# Comment values are already inserted current transaction is aborted, commands ignored until end of transaction block
#
# Comment values are already inserted current transaction is aborted, commands ignored until end of transaction block
#
# Comment values are already inserted current transaction is aborted, commands ignored until end of transaction block
#
# ...

# %%
video_ids=get_video_ids(channel_info)
video_ids
#tx1UQseMJpk
# Out:
# ['WzyfatXppwo',
#  'tx1UQseMJpk',
#  '52jCUplBKd8',
#  'x7RIFbuaKS4',
#  'yDyb0HIQby0',
#  'DagqIHmkadM',
#  'aQEgnwvW2OY',
#  'M-gXuceWwf4',
#  'mSYxNMdwzUc',
#  'Qc7E9CZUHb4',
#  '9qOwRb5mIl0',
#  'xEPfCl_Frhs',
#  'Z9VhzKI3CVM',
#  'nWa6aFWopA8',
#  '-NFueNFvTuE',
#  'k6WJxHPDI6w',
#  '7uLEzxdXuiA',
#  'C_1Dp4a-4VM',
#  'ZJ9uh0BVJy0',
#  '_mpv6eiuEHI',
#  'Q-TTKm2kEe8',
#  'jOmktpt_nBE',
#  'h6BQqGrLLJM',
#  'Ip4CB7hlPcw',
#  'RDMJWI0pUcE',
#  'bhmQMrmG8d8',
#  'ICkESUQRWWk',
#  'Y-EDa1cIGiM',
#  '57XUSY4PKDY',
#  '_UtIeYxcxUc',
#  'CAe43gSJQCQ',
#  'LPJKJLVTbVE',
#  'zc_BAnxjG2A',
#  'uT_z4BZpcZc',
#  'pDe_NSgZUX8',
#  'TDymoXfczY0',
#  '7xaftUFlAfo',
#  'DXuB-pMG2NI',
#  '4zRqjS9g_XE',
#  'UiegvMvLopE',
#  'w9KjZpuWmNw',
#  'yDMOsIr7SB0',
#  '3tPV6-J0QBo',
#  'oOQscFU8PCs',
#  'rcxzlzDyTZY',
#  'u0S0c0GfOsM',
#  '_LMUBoIzgOk',
#  'IBCAZRhiiHI',
#  'cBr9hb3MysY',
#  'T3-Ypyzd5kc',
#  'MBl7acFySUg',
#  'k7goZTH1u30',
#  'MieUYmKj5z8',
#  'l6C6sgE_YFw',
#  '7iTnl4gRJZc',
# ...

# %%
def Playlist(channel_content):
    client=pymg.MongoClient("mongodb+srv://maheshwariswaminathan:ocJ5zarf3JSDRQu3@cluster0.gf3ephp.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0")
    db=client["Youtube_Content"]


    mydb=psyc.connect(host="localhost",
                        user="postgres",
                        password="maksi@2024",
                        database="Youtube_Content",
                        port="5432")
    cursor=mydb.cursor()

    try:
        create_query='''create table if not exists playlist(Playlist_Id varchar(100) primary key,
                                                            Title varchar(100),
                                                            Channel_Id varchar(80),
                                                            Channel_Name varchar(100),
                                                            PublishedAt timestamp,
                                                            Total_Videos bigint)'''
        cursor.execute(create_query)
        mydb.commit()

    except Exception as error:
        print("Playlist table already created",error)

# %%
for index,row in df_channel_info.iterrows():
    # print("Row values: ", row)
    insert_sql='''insert into channels(Channel_Name,
                                       Channel_Id,
                                       Subscribers,
                                       Channel_Views,
                                       Total_Videos,
                                       Channel_Description,
                                       Playlist_Id)
    
                                       values(%s,%s,%s,%s,%s,%s,%s)
                                       on conflict (Channel_Id)
                                       do update set Channel_Name = EXCLUDED.Channel_Name,
                                       Subscribers = EXCLUDED.Subscribers,
                                       Channel_Views = EXCLUDED.Channel_Views,
                                       Total_Videos = EXCLUDED.Total_Videos,
                                       Channel_Description = EXCLUDED.Channel_Description,
                                       Playlist_Id = EXCLUDED.Playlist_Id'''

    values=(row["Channel_Name"],
            row["Channel_Id"],
            row["Subscribers"],
            row["Channel_views"],
            row["Total_Videos"],
            row["Channel_Description"],
            row["Playlist_Id"])  
    try:
        cursor.execute(insert_sql,values)      
        mydb.commit()
    except Exception as error:
        print("Error occured during insertion",error)
        mydb.rollback()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
    
    else:

        single_channel_details= []
        coll1=db["channel_details"]
        for ch_data in coll1.find({"channel_information.Channel_Name":channel_name_s},{"_id":0}):
            single_channel_details.append(ch_data["channel_information"])

        df_single_channel= pd.DataFrame(single_channel_details)



        for index,row in df_single_channel.iterrows():
            insert_query='''insert into channels(Channel_Name ,
                                                Channel_Id,
                                                Subscribers,
                                                Views,
                                                Total_Videos,
                                                Channel_Description,
                                                Playlist_Id)
]
                                                values(%s,%s,%s,%s,%s,%s,%s)
                                                on conflict (Channel_Id)
                                                do update set Channel_Name = EXCLUDED.Channel_Name,
                                                Subscribers = EXCLUDED.Subscribers,
                                                Views = EXCLUDED.Views,
                                                Total_Videos = EXCLUDED.Total_Videos,
                                                Channel_Description = EXCLUDED.Channel_Description,
                                                Playlsit_Id = EXCLUDED.Playlsit_Id'''
            values=(row['Channel_Name'],
                    row['Channel_Id'],
                    row['Subscribers'],
                    row['Views'],
                    row['Total_Videos'],
                    row['Channel_Description'],
                    row['Playlist_Id'])

            try:
                cursor.execute(insert_query,values)
                mydb.commit()

            except:
                print("Channel values are already inserted")

# %%
client=pymg.MongoClient("mongodb+srv://maheshwariswaminathan:maksimgdb@cluster0.gf3ephp.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0")
db=client["Youtube_harvested_data"]
coll1=db["channel_info"]
x={"name":"max","year":"2024"}
coll1.insert_one(x)

# %%
def get_video_info(video_ids):
    video_data=[]
    for video_id in video_ids:
        request=youtube.videos().list(
            part="snippet,ContentDetails,statistics",
            id=video_id
        )
        response=request.execute()

        for item in response["items"]:
            data=dict(Channel_Name=item['snippet']['channelTitle'],
                    Channel_Id=item['snippet']['channelId'],
                    Video_Id=item['id'],
                    Title=item['snippet']['title'],
                    Tags=item['snippet'].get('tags'),
                    Thumbnail=item['snippet']['thumbnails']['default']['url'],
                    Description=item['snippet'].get('description'),
                    Published_Date=item['snippet']['publishedAt'],
                    Duration=item['contentDetails']['duration'],
                    Views=item['statistics'].get('viewCount'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[265], line 1
# ----> 1 video_content
#
# NameError: name 'video_content' is not defined

# %%
data = {"channel_id":response['items'][0]['snippet']['channelId'],
"vtitle":response['items'][0]['snippet']['title'],
"channel_name":response['items'][0]['snippet']['channelTitle'],
"vdesc":response['items'][0]['snippet']['description'],
"vpubat":response['items'][0]['snippet']['publishedAt'],
"vthumb":response['items'][0]['snippet']['thumbnails'],
"vduration":response['items'][0]['contentDetails']['duration'],
"contentRating":response['items'][0]['contentDetails']['contentRating'],
"caption":response['items'][0]['contentDetails']['caption'],
"licensedContent":response['items'][0]['contentDetails']['licensedContent'],
"vvwcount":response['items'][0]['statistics']['viewCount'],
"vlikecount":response['items'][0]['statistics']['likeCount'],
"vcommentcount":response['items'][0]['statistics']['commentCount'],
"vfavcount":response['items'][0]['statistics']['favoriteCount'] 
}
data
# Out:
# {'kind': 'youtube#playlistItemListResponse',
#  'etag': '4E2Xqy96QNdTzydvHKa85UG8W-I',
#  'nextPageToken': 'EAAafVBUOkNBVWlFREV5UlVaQ00wSXhRelUzUkVVMFJURW9BVWlUbzQzN3hkbUZBMUFCV2pnaVEyaG9WbFpZU1hSYU1WSnRVMVJrYUdSVWJGWlpWVlp4Vkd0T2FXSnVRbVpVYm1OVFJFRnFXbXcyUjNoQ2FFTTBNazB6YTBGbkln',
#  'items': [{'kind': 'youtube#playlistItem',
#    'etag': 'ZtehBEuUMoCGB85_Ohc86JBs-I4',
#    'id': 'VVVyLWdUZkk3YXU5VWFFak5DYm5wX053Lld6eWZhdFhwcHdv',
#    'contentDetails': {'videoId': 'WzyfatXppwo',
#     'videoPublishedAt': '2024-04-23T03:47:15Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'PmQ6WNf3c3cp6Vydv0c7eZtzao8',
#    'id': 'VVVyLWdUZkk3YXU5VWFFak5DYm5wX053LnR4MVVRc2VNSnBr',
#    'contentDetails': {'videoId': 'tx1UQseMJpk',
#     'videoPublishedAt': '2024-04-23T03:44:15Z'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': '7kJ9TbSkByneP-RK10LxmTuciLQ',
#    'id': 'VVVyLWdUZkk3YXU5VWFFak5DYm5wX053LjUyakNVcGxCS2Q4',
#    'contentDetails': {'videoId': '52jCUplBKd8',
# ...

# %%
request1 = youtube.playListItems().list(
                part="snippet,contentDetails",
                playlistID='a',
                maxResults=50
                #pageToken=next_page_token
                )
response1=request1.execute()
# Out:
#   Cell In[197], line 6
#     )
#     ^
# SyntaxError: positional argument follows keyword argument

# %%
def get_video_ids(c_id):
    video_ids=[]
    request=youtube.channels().list(part="snippet,contentDetails,statistics",
                        id=c_id)
    response = request.execute()
    PlayList_ID=response['items'][0]['contentDetails']['relatedPlaylists']['uploads']
    next_page_token=None

# %%
def get_videos_ids(Playlist_Id):
    video_ids=[]
    response=youtube.channels().list(id=channel_id,
                                    part='contentDetails').execute()
    Playlist_Id=response['items'][0]['contentDetails']['relatedPlaylists']['uploads']

    next_page_token=None

    while True:
        response1=youtube.playlistItems().list(
                                            part='snippet',
                                            playlistId=Playlist_Id,
                                            maxResults=50,
                                            pageToken=next_page_token).execute()
        for i in range(len(response1['items'])):
            video_ids.append(response1['items'][i]['snippet']['resourceId']['videoId'])
        next_page_token=response1.get('nextPageToken')

        if next_page_token is None:
            break
    return video_ids

# %%
def video_detailss(c_id):
    request=youtube.videos().list(
    part="snippet,contentDetails,statistics",
    id=c_id
    )
    response = request.execute()
    data = {"channel_id":response['items'][0]['snippet']['channelId'],
    "vtitle":response['items'][0]['snippet']['title'],
    "channel_name":response['items'][0]['snippet']['channelTitle'],
    "vdesc":response['items'][0]['snippet']['description'],
    "vpubat":response['items'][0]['snippet']['publishedAt'],
    "vthumb":response['items'][0]['snippet']['thumbnails'],
    "vduration":response['items'][0]['contentDetails']['duration'],
    "contentRating":response['items'][0]['contentDetails']['contentRating'],
    "caption":response['items'][0]['contentDetails']['caption'],
    "licensedContent":response['items'][0]['contentDetails']['licensedContent'],
    "vvwcount":response['items'][0]['statistics']['viewCount'],
    "vlikecount":response['items'][0]['statistics']['likeCount'],
    "vcommentcount":response['items'][0]['statistics']['commentCount'],
    "vfavcount":response['items'][0]['statistics']['favoriteCount'] 
    }
    return data

# %%
request = youtube.comments().list(
part="snippet,id",
id="GAQ2ktOaAc0" #to check dislike functionality
#id="eiGdsH1g20k"
)
response = request.execute()

# %%
Channel_ID='UCGZhNQ6mRnvLa0_oVJNG_kA'
print(Channel_ID)
client=pymg.MongoClient("mongodb+srv://maheshwariswaminathan:ocJ5zarf3JSDRQu3@cluster0.gf3ephp.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0")
db=client["Youtube_Content"]
coll=db["channel_content"]
print(coll.find_one({'channel_information.Channel_Id' : Channel_ID}))
# coll.delete_many({'channel_information.Channel_Id' : Channel_ID})
# Out:
# {'_id': ObjectId('663f8b8f54876cc7297d90a9'), 'channel_information': {'Channel_Id': 'UCGZhNQ6mRnvLa0_oVJNG_kA', 'Channel_Name': 'LP', 'Channel_Description': 'My album Love Lines is out now!\nhttps://lp.lnk.to/LoveLinesID\n', 'PublishedAt': '2011-06-03T19:41:22Z', 'Playlist_Id': 'UUGZhNQ6mRnvLa0_oVJNG_kA', 'Subscribers': '4640000', 'Channel_views': '3255553524', 'Total_Videos': '462'}, 'playlist_information': [{'Playlist_Id': 'PLyv7j-kfoPR8n4U5lruf2RbWDXsLmFUek', 'Title': 'Love Lines', 'Channel_Id': 'UCGZhNQ6mRnvLa0_oVJNG_kA', 'Channel_Name': 'LP', 'PublishedAt': '2023-05-10T17:30:27Z', 'Video_Count': 12}, {'Playlist_Id': 'PLyv7j-kfoPR8CQ3XgaV1N0OSu94ZBSnW0', 'Title': 'Goodbye', 'Channel_Id': 'UCGZhNQ6mRnvLa0_oVJNG_kA', 'Channel_Name': 'LP', 'PublishedAt': '2021-08-06T17:22:36Z', 'Video_Count': 2}, {'Playlist_Id': 'PLyv7j-kfoPR96xxs5rhbhMCMZB76Reycj', 'Title': 'One Last Time', 'Channel_Id': 'UCGZhNQ6mRnvLa0_oVJNG_kA', 'Channel_Name': 'LP', 'PublishedAt': '2021-05-20T20:08:41Z', 'Video
# ...
